# %%
#import necessary libraries
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.image as mping
import seaborn as sns

# %%
cd D:\VIT CLASSES\Sem 4\ML LAB\Research\ccmandoadataset.csv
# Out:
# D:\VIT CLASSES\Sem 4\ML LAB\Research\ccmandoadataset.csv

# %%
#importing dataset using pandas
df=pd.read_csv("ccmandoadataset.csv")
df
# Out:
#        index  Customer Number Offer Accepted     Reward Mailer Type  \
# 0          0                1             No  Air Miles      Letter
# 1          1                2             No  Air Miles      Letter
# 2          2                3             No  Air Miles    Postcard
# 3          3                4             No  Air Miles      Letter
# 4          4                5             No  Air Miles      Letter
# ...      ...              ...            ...        ...         ...
# 17995  17995            17996             No  Cash Back      Letter
# 17996  17996            17997             No  Cash Back      Letter
# 17997  17997            17998             No  Cash Back      Letter
# 17998  17998            17999             No  Cash Back      Letter
# 17999  17999            18000             No  Cash Back      Letter
#
#       Income Level  # Bank Accounts Open Overdraft Protection Credit Rating  \
# ...

# %%
# number of rows and columns
df.shape
# Out:
# (18000, 18)

# %%
#basic information about the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18000 entries, 0 to 17999
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   index                 18000 non-null  int64
#  1   Customer Number       18000 non-null  int64
#  2   Offer Accepted        18000 non-null  object
#  3   Reward                18000 non-null  object
#  4   Mailer Type           18000 non-null  object
#  5   Income Level          18000 non-null  object
#  6   # Bank Accounts Open  18000 non-null  int64
#  7   Overdraft Protection  18000 non-null  object
#  8   Credit Rating         18000 non-null  object
#  9   # Credit Cards Held   18000 non-null  int64
#  10  # Homes Owned         18000 non-null  int64
#  11  Household Size        18000 non-null  int64
#  12  Own Your Home         18000 non-null  object
#  13  Average Balance       17976 non-null  float64
#  14  Q1 Balance            17976 non-null  float64
# ...

# %%
#disply of top 10 rows
df.head(10)
# Out:
#    index  Customer Number Offer Accepted     Reward Mailer Type Income Level  \
# 0      0                1             No  Air Miles      Letter         High
# 1      1                2             No  Air Miles      Letter       Medium
# 2      2                3             No  Air Miles    Postcard         High
# 3      3                4             No  Air Miles      Letter       Medium
# 4      4                5             No  Air Miles      Letter       Medium
# 5      5                6             No  Air Miles      Letter       Medium
# 6      6                7             No  Air Miles      Letter       Medium
# 7      7                8             No  Cash Back    Postcard          Low
# 8      8                9             No  Air Miles    Postcard       Medium
# 9      9               10             No  Air Miles      Letter         High
#
#    # Bank Accounts Open Overdraft Protection Credit Rating  \
# 0                     1                   No          High
# ...

# %%
#determing whether the dataset has null values
df.isnull().sum()
# Out:
# index                    0
# Customer Number          0
# Offer Accepted           0
# Reward                   0
# Mailer Type              0
# Income Level             0
# # Bank Accounts Open     0
# Overdraft Protection     0
# Credit Rating            0
# # Credit Cards Held      0
# # Homes Owned            0
# Household Size           0
# Own Your Home            0
# Average Balance         24
# Q1 Balance              24
# Q2 Balance              24
# Q3 Balance              24
# Q4 Balance              24
# dtype: int64

# %% [raw]
# #Checking duplicate rows

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [index, Customer Number, Offer Accepted, Reward, Mailer Type, Income Level, # Bank Accounts Open, Overdraft Protection, Credit Rating, # Credit Cards Held, # Homes Owned, Household Size, Own Your Home, Average Balance, Q1 Balance, Q2 Balance, Q3 Balance, Q4 Balance]
# Index: []

# %% [markdown]
# # Quantitative Analysis

# %%
#unique values in target column
df['Offer Accepted'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
df['Offer Accepted'].value_counts().plot(kind='pie', autopct='%1.1f%%', 
                                         shadow=True)
plt.title("Class distribution")
# Out:
# Text(0.5, 1.0, 'Class distribution')

# %%
plt.plot(df['Average Balance'])
plt.title("Average Balance in Customer Account")
# Out:
# Text(0.5, 1.0, 'Average Balance in Customer Account')

# %%
plt.subplot(2,2,1)
plt.plot(df['Q1 Balance'],color='red')
plt.xlim(0,1000)
plt.ylim(0,3000)
plt.title('Q1 Balance')

plt.subplot(2,2,2)
plt.plot(df['Q2 Balance'],color='green')
plt.xlim(0,1000)
plt.ylim(0,3000)
plt.title('Q2 Balance')


plt.subplot(2,2,3)
plt.plot(df['Q3 Balance'],color='black')
plt.xlim(0,1000)
plt.ylim(0,3000)
plt.title('Q3 Balance')

plt.subplot(2,2,4)
plt.plot(df['Q4 Balance'],color='purple')
plt.xlim(0,1000)
plt.ylim(0,3000)
plt.title('Q4 Balance')

# Add some spacing between subplots
plt.subplots_adjust(hspace=0.4)
plt.subplots_adjust(wspace=0.4)

# %%
#exploring reward section
df['Reward'].value_counts()
# Out:
# Air Miles    6061
# Cash Back    5999
# Points       5940
# Name: Reward, dtype: int64

# %%
ax = sns.countplot(x='Offer Accepted', hue = 'Reward', data=df)
for i in ax.containers:
    ax.bar_label(i,)
plt.title("Customer accepted offer categorised into Rewards")
# Out:
# Text(0.5, 1.0, 'Customer accepted offer categorised into Rewards')

# %%
ax = sns.countplot(x='Offer Accepted', hue = 'Income Level', data=df)
for i in ax.containers:
    ax.bar_label(i,)
plt.title("Customer accepted offer categorised into Income Level")
# Out:
# Text(0.5, 1.0, 'Customer accepted offer categorised into Income Level')

# %%
ax = sns.countplot(x='Offer Accepted', hue = 'Credit Rating', data=df)
for i in ax.containers:
    ax.bar_label(i,)
plt.title("Customer accepted offer categorised into Credit Rating")
# Out:
# Text(0.5, 1.0, 'Customer accepted offer categorised into Credit Rating')

# %%
ax = sns.countplot(x='Offer Accepted', hue = '# Credit Cards Held', data=df)
for i in ax.containers:
    ax.bar_label(i,)
plt.title("Customer accepted offer categorised into # Credit Cards Held")
# Out:
# Text(0.5, 1.0, 'Customer accepted offer categorised into # Credit Cards Held')

# %%
ax = sns.countplot(x='# Credit Cards Held',data=df)
for i in ax.containers:
    ax.bar_label(i,)
plt.title("No. of credit cards held over the dataset")
# Out:
# Text(0.5, 1.0, 'No. of credit cards held over the dataset')

# %%
df1=df.drop(['index','Customer Number','Average Balance',
             'Q1 Balance','Q2 Balance','Q3 Balance','Q4 Balance'],axis=1)
df1
# Out:
#       Offer Accepted     Reward Mailer Type Income Level  \
# 0                 No  Air Miles      Letter         High
# 1                 No  Air Miles      Letter       Medium
# 2                 No  Air Miles    Postcard         High
# 3                 No  Air Miles      Letter       Medium
# 4                 No  Air Miles      Letter       Medium
# ...              ...        ...         ...          ...
# 17995             No  Cash Back      Letter         High
# 17996             No  Cash Back      Letter         High
# 17997             No  Cash Back      Letter         High
# 17998             No  Cash Back      Letter       Medium
# 17999             No  Cash Back      Letter          Low
#
#        # Bank Accounts Open Overdraft Protection Credit Rating  \
# 0                         1                   No          High
# 1                         1                   No        Medium
# 2                         2                   No        Medium
# ...

# %%
df1.shape
# Out:
# (18000, 11)

# %%
df1['Mailer Type'].unique()
# Out:
# array(['Letter', 'Postcard'], dtype=object)

# %%
df1['Reward'].unique()
# Out:
# array(['Air Miles', 'Cash Back', 'Points'], dtype=object)

# %%
d = {'Low': 0, 'Medium': 1, 'High': 2}
df1['Income Level'] = df1['Income Level'].map(d)
df1['Credit Rating'] = df1['Credit Rating'].map(d)
e = {'Yes': 1, 'No': 0}
df1['Overdraft Protection'] = df1['Overdraft Protection'].map(e)
df1['Offer Accepted'] = df1['Offer Accepted'].map(e)
df1['Own Your Home'] = df1['Own Your Home'].map(e)
f = {'Letter':0, 'Postcard':1}
df1['Mailer Type'] = df1['Mailer Type'].map(f)
g = {'Air Miles': 0, 'Cash Back': 1, 'Points': 2}
df1['Reward'] = df1['Reward'].map(g)
df1
# Out:
#        Offer Accepted  Reward  Mailer Type  Income Level  \
# 0                   0       0            0             2
# 1                   0       0            0             1
# 2                   0       0            1             2
# 3                   0       0            0             1
# 4                   0       0            0             1
# ...               ...     ...          ...           ...
# 17995               0       1            0             2
# 17996               0       1            0             2
# 17997               0       1            0             2
# 17998               0       1            0             1
# 17999               0       1            0             0
#
#        # Bank Accounts Open  Overdraft Protection  Credit Rating  \
# 0                         1                     0              2
# 1                         1                     0              1
# 2                         2                     0              1
# ...

# %%
X = df1.drop('Offer Accepted', axis='columns')
X
# Out:
#        Reward  Mailer Type  Income Level  # Bank Accounts Open  \
# 0           0            0             2                     1
# 1           0            0             1                     1
# 2           0            1             2                     2
# 3           0            0             1                     2
# 4           0            0             1                     1
# ...       ...          ...           ...                   ...
# 17995       1            0             2                     1
# 17996       1            0             2                     1
# 17997       1            0             2                     1
# 17998       1            0             1                     1
# 17999       1            0             0                     2
#
#        Overdraft Protection  Credit Rating  # Credit Cards Held  \
# 0                         0              2                    2
# 1                         0              1                    2
# ...

# %%
Y = df1['Offer Accepted']
Y
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 17995    0
# 17996    0
# 17997    0
# 17998    0
# 17999    0
# Name: Offer Accepted, Length: 18000, dtype: int64

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report

# %%
X_train, X_test, y_train, y_test = train_test_split(X,Y, test_size=0.2,random_state=100)

# %%
logreg = LogisticRegression()

# Fit the model to the training data
logreg.fit(X_train, y_train)

# Predict the target variable for the test data
y_pred = logreg.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
print('Accuracy: {:.2f}%'.format((y_pred == y_test).mean()*100))
# Out:
# Accuracy: 95.14%

# %%
print(classification_report(y_test, y_pred,zero_division=0))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.98      3425
#            1       0.00      0.00      0.00       175
#
#     accuracy                           0.95      3600
#    macro avg       0.48      0.50      0.49      3600
# weighted avg       0.91      0.95      0.93      3600

# %% [markdown]
# # Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=100)

# %%
dtc = DecisionTreeClassifier()

# Fit the XGBoost model to the training data
dtc.fit(X_train, y_train)

# Predict the target variable for the test data
y_pred = dtc.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
print('Accuracy: {:.2f}%'.format((y_pred == y_test).mean()*100))
# Out:
# Accuracy: 93.08%

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.98      0.96      3425
#            1       0.11      0.06      0.07       175
#
#     accuracy                           0.93      3600
#    macro avg       0.53      0.52      0.52      3600
# weighted avg       0.91      0.93      0.92      3600

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2,random_state=100)

# %%
# Create the random forest classifier with 100 trees
rf = RandomForestClassifier(n_estimators=100,random_state=42)

# Fit the model to the training data
rf.fit(X_train, y_train)

# Predict the target variable for the test data
y_pred = rf.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
print('Accuracy: {:.2f}%'.format((y_pred == y_test).mean()*100))
# Out:
# Accuracy: 94.08%

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97      3425
#            1       0.19      0.07      0.10       175
#
#     accuracy                           0.94      3600
#    macro avg       0.57      0.53      0.54      3600
# weighted avg       0.92      0.94      0.93      3600

# %% [markdown]
# # KNeighbors

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report

# %%
X_train, X_test, y_train, y_test = train_test_split(X,Y, test_size=0.2,random_state=100)

# %%
knn = KNeighborsClassifier(n_neighbors=3)

# Fit the model to the training data
knn.fit(X_train, y_train)

# Predict the target variable for the test data
y_pred = knn.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
print('Accuracy: {:.2f}%'.format((y_pred == y_test).mean()*100))
# Out:
# Accuracy: 93.58%

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.98      0.97      3425
#            1       0.08      0.03      0.04       175
#
#     accuracy                           0.94      3600
#    macro avg       0.51      0.51      0.50      3600
# weighted avg       0.91      0.94      0.92      3600

# %% [markdown]
# # SVM (Suppoert Vector Machine)

# %%
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
X_train, X_test, y_train, y_test = train_test_split(X,Y, test_size=0.2, random_state=100)

# %%
svm = SVC(kernel='linear')

# Fit the model to the training data
svm.fit(X_train, y_train)

# Predict the target variable for the test data
y_pred = svm.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
print('Accuracy: {:.2f}%'.format((y_pred == y_test).mean()*100))
# Out:
# Accuracy: 95.14%

# %%
print(classification_report(y_test, y_pred,zero_division=0))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.98      3425
#            1       0.00      0.00      0.00       175
#
#     accuracy                           0.95      3600
#    macro avg       0.48      0.50      0.49      3600
# weighted avg       0.91      0.95      0.93      3600

# %% [markdown]
# # XGBoost

# %%
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, accuracy_score

# %%
X_train, X_test, y_train, y_test = train_test_split(X,Y, test_size=0.2,random_state=100)

# %%
xgb_clf = xgb.XGBClassifier()

# Fit the XGBoost model to the training data
xgb_clf.fit(X_train, y_train)

# Predict the target variable for the test data using the XGBoost model
y_pred_xgb = xgb_clf.predict(X_test)

# %%
accuracy_xgb = accuracy_score(y_test, y_pred_xgb)
print('Accuracy: {:.2f}%'.format((y_pred == y_test).mean()*100))
# Out:
# Accuracy: 95.14%

# %%
report_xgb = classification_report(y_test, y_pred_xgb)
print(report_xgb)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97      3425
#            1       0.18      0.02      0.03       175
#
#     accuracy                           0.95      3600
#    macro avg       0.56      0.51      0.50      3600
# weighted avg       0.91      0.95      0.93      3600

# %% [markdown]
# # Stacking

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import cross_val_predict, train_test_split
from sklearn.metrics import accuracy_score

# %%
X_train, X_test, y_train, y_test = train_test_split(X,Y,test_size=0.2, random_state=100)

# %%
model_1_list = [LogisticRegression(),DecisionTreeClassifier(),
                RandomForestClassifier(n_estimators=100),KNeighborsClassifier(n_neighbors=3),xgb.XGBClassifier()]
model_2_list = [LogisticRegression(),DecisionTreeClassifier(),
                RandomForestClassifier(n_estimators=100),KNeighborsClassifier(n_neighbors=3),
                SVC(kernel='linear'),xgb.XGBClassifier()]

output_list = []


for i in model_1_list:
    model_1 = i
    model_2 = GradientBoostingClassifier(n_estimators=100, learning_rate=0.1, max_depth=3)

    # Use cross-validation to generate meta-features
    m1_meta_features = cross_val_predict(model_1, X_train, y_train, cv=5, method='predict_proba')[:, 1]
    m2_meta_features = cross_val_predict(model_2, X_train, y_train, cv=5, method='predict_proba')[:, 1]
    meta_features = pd.DataFrame({'Model_1': m1_meta_features, 'Gradient Boosting': m2_meta_features})

    # Train the base models on the full training set
    model_1.fit(X_train, y_train)
    model_2.fit(X_train, y_train)

    # Generate meta-features for the test set
    m1_test_meta_features = model_1.predict_proba(X_test)[:, 1]
    m2_test_meta_features = model_2.predict_proba(X_test)[:, 1]
    test_meta_features = pd.DataFrame({'Model_1': m1_test_meta_features, 'Gradient Boosting': m2_test_meta_features})

    for j in model_2_list:
        meta_model = j
        meta_model.fit(meta_features, y_train)
        y_pred = meta_model.predict(test_meta_features)
        #print('Accuracy: {:.2f}%'.format(accuracy_score(y_test, y_pred)*100))
        output = '{:.2f}%'.format(accuracy_score(y_test, y_pred)*100)
        output_list.append(output)

dff1 = pd.DataFrame([output_list[i:i+6] for i in range(0, 30, 6)],
                  index=['Logistic','DecisionTree',
                                 'RandomForest','KNeighbors','XGBoost'],
                  columns=['Logistic','DecisionTree',
                                   'RandomForest','KNeighbors','SVM','XGBoost'])
print(dff1)
# Out:
#              Logistic DecisionTree RandomForest KNeighbors     SVM XGBoost
# Logistic       95.06%       91.81%       94.75%     94.14%  95.14%  95.00%
# DecisionTree   95.03%       92.14%       92.36%     93.86%  95.14%  95.11%
# RandomForest   95.03%       91.67%       93.86%     93.67%  95.14%  94.92%
# KNeighbors     95.06%       92.22%       92.03%     94.22%  95.14%  95.08%
# XGBoost        95.03%       90.72%       94.67%     93.50%  95.14%  94.72%

# %% [markdown]
# # Ensembling using Voting Classifier

# %%
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, VotingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_predict, train_test_split
from sklearn.metrics import accuracy_score

# %%
X_train, X_test, y_train, y_test = train_test_split(X,Y, 
                                                    test_size=0.2, random_state=100)

# %%
models = [LogisticRegression(),DecisionTreeClassifier(),
          RandomForestClassifier(),KNeighborsClassifier(n_neighbors=3),
          SVC(kernel='linear'),xgb.XGBClassifier()]

output_list = []
    
for i in models:
    model_1 = i
    for j in models:
        model_2 = j
        model_3 = GradientBoostingClassifier(n_estimators=100, learning_rate=0.1, max_depth=3, random_state=100)

        ensemble_model = VotingClassifier(estimators=[('m1', model_1),('m2', model_2),('m3', model_3)], voting='hard')
        ensemble_accuracy = cross_val_predict(ensemble_model, X_train, y_train, cv=5)
        ensemble_model.fit(X_train, y_train)
        y_pred = ensemble_model.predict(X_test)
        
        
        output = '{:.2f}%'.format(accuracy_score(y_test, y_pred)*100)
        output_list.append(output)

dff2 = pd.DataFrame([output_list[i:i+6] for i in range(0, 36, 6)],
                  index=['Logistic','DecisionTree','RandomForest','KNeighbors','SVM','XGBoost'],
                  columns=['Logistic','DecisionTree','RandomForest','KNeighbors','SVM','XGBoost'])
print(dff2)
# Out:
#              Logistic DecisionTree RandomForest KNeighbors     SVM XGBoost
# Logistic       95.14%       95.06%       95.06%     95.08%  95.14%  95.06%
# DecisionTree   95.06%       93.08%       94.19%     94.61%  95.06%  94.94%
# RandomForest   95.06%       94.19%       94.25%     94.61%  95.06%  95.00%
# KNeighbors     95.08%       94.61%       94.53%     93.58%  95.08%  94.94%
# SVM            95.14%       95.06%       95.06%     95.08%  95.14%  95.06%
# XGBoost        95.06%       94.94%       94.92%     94.94%  95.06%  94.83%

# %% [markdown]
# # Bagging

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2,random_state=100)

# %%
models = [LogisticRegression(),DecisionTreeClassifier(),
          RandomForestClassifier(),KNeighborsClassifier(n_neighbors=3),
          SVC(kernel='linear'),xgb.XGBClassifier()]

output_list = []

for i in models:
    tree=i
    
    # define the bagging classifier with 10 estimators
    bagging = BaggingClassifier(estimator=tree, n_estimators=10)

    # train the bagging classifier on the training data
    bagging.fit(X_train, y_train)

    # evaluate the bagging classifier on the test data
    accuracy = bagging.score(X_test, y_test)
    accuracy = '{:.2f}%'.format(accuracy*100)
    output_list.append(accuracy)

dff3 = pd.DataFrame([output_list],index=['Accuracy'],
                 columns=['Logistic','DecisionTree','RandomForest','KNeighbors','SVM','XGBoost'])
print(dff3)
# Out:
#          Logistic DecisionTree RandomForest KNeighbors     SVM XGBoost
# Accuracy   95.14%       93.42%       94.42%     94.19%  95.14%  94.94%

# %% [markdown]
# # Majority Voting

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2,random_state=100)

# %%
models = [LogisticRegression(),DecisionTreeClassifier(),
          RandomForestClassifier(),KNeighborsClassifier(n_neighbors=3),
          SVC(kernel='linear'),xgb.XGBClassifier()]

output_list = []
    
for i in models:
    model_1 = i
    for j in models:  
        model_2 = VotingClassifier(estimators=[('m1', model_1), ('m2', model_2), ('m3', model_3)], voting='hard')
        model_3 = j
        
        # Train each base model on the full training set
        model_1.fit(X_train, y_train)
        model_2.fit(X_train, y_train)
        model_3.fit(X_train, y_train)
        
        pred_1 = model_1.predict(X_test)
        pred_2 = model_2.predict(X_test)
        pred_3 = model_3.predict(X_test)
        
        # Combine the predictions using majority voting
        voting_pred = (pred_1 + pred_2 + pred_3) / 3
        voting_pred = [1 if x > 0.5 else 0 for x in voting_pred]

        output = '{:.2f}%'.format(accuracy_score(y_test, voting_pred)*100)
        output_list.append(output)

dff4 = pd.DataFrame([output_list[i:i+6] for i in range(0, 36, 6)],
                  index=['Logistic','DecisionTree','RandomForest','KNeighbors','SVM','XGBoost'],
                  columns=['Logistic','DecisionTree','RandomForest','KNeighbors','SVM','XGBoost'])
print(dff4)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[67], line 19
#      16 model_3.fit(X_train, y_train)
#      18 pred_1 = model_1.predict(X_test)
# ---> 19 pred_2 = model_2.predict(X_test)
#      20 pred_3 = model_3.predict(X_test)
#      22 # Combine the predictions using majority voting
#
# File ~\AppData\Roaming\Python\Python39\site-packages\sklearn\ensemble\_voting.py:367, in VotingClassifier.predict(self, X)
#     364     maj = np.argmax(self.predict_proba(X), axis=1)
#     366 else:  # 'hard' voting
# --> 367     predictions = self._predict(X)
#     368     maj = np.apply_along_axis(
#     369         lambda x: np.argmax(np.bincount(x, weights=self._weights_not_none)),
#     370         axis=1,
#     371         arr=predictions,
#     372     )
#     374 maj = self.le_.inverse_transform(maj)
#
# ...

# %% [markdown]
# # Naive Bayes Classifier

# %% [markdown]
# #Considering remaining attributes which were dropped

# %%
df2=df.drop(['index','Customer Number'],axis=1)
df2
# Out:
#       Offer Accepted     Reward Mailer Type Income Level  \
# 0                 No  Air Miles      Letter         High
# 1                 No  Air Miles      Letter       Medium
# 2                 No  Air Miles    Postcard         High
# 3                 No  Air Miles      Letter       Medium
# 4                 No  Air Miles      Letter       Medium
# ...              ...        ...         ...          ...
# 17995             No  Cash Back      Letter         High
# 17996             No  Cash Back      Letter         High
# 17997             No  Cash Back      Letter         High
# 17998             No  Cash Back      Letter       Medium
# 17999             No  Cash Back      Letter          Low
#
#        # Bank Accounts Open Overdraft Protection Credit Rating  \
# 0                         1                   No          High
# 1                         1                   No        Medium
# 2                         2                   No        Medium
# ...

# %%
d = {'Low': 0, 'Medium': 1, 'High': 2}
df2['Income Level'] = df2['Income Level'].map(d)
df2['Credit Rating'] = df2['Credit Rating'].map(d)
e = {'Yes': 1, 'No': 0}
df2['Overdraft Protection'] = df2['Overdraft Protection'].map(e)
df2['Offer Accepted'] = df2['Offer Accepted'].map(e)
df2['Own Your Home'] = df2['Own Your Home'].map(e)
f = {'Letter':0, 'Postcard':1}
df2['Mailer Type'] = df2['Mailer Type'].map(f)
g = {'Air Miles': 0, 'Cash Back': 1, 'Points': 2}
df2['Reward'] = df2['Reward'].map(g)
df2
# Out:
#        Offer Accepted  Reward  Mailer Type  Income Level  \
# 0                   0       0            0             2
# 1                   0       0            0             1
# 2                   0       0            1             2
# 3                   0       0            0             1
# 4                   0       0            0             1
# ...               ...     ...          ...           ...
# 17995               0       1            0             2
# 17996               0       1            0             2
# 17997               0       1            0             2
# 17998               0       1            0             1
# 17999               0       1            0             0
#
#        # Bank Accounts Open  Overdraft Protection  Credit Rating  \
# 0                         1                     0              2
# 1                         1                     0              1
# 2                         2                     0              1
# ...

# %%
for i in df2.columns[df2.isnull().any(axis=0)]:    
    df2[i].fillna(df2[i].mean(),inplace=True)

# %%
X = df2.drop('Offer Accepted', axis='columns')
X
# Out:
#        Reward  Mailer Type  Income Level  # Bank Accounts Open  \
# 0           0            0             2                     1
# 1           0            0             1                     1
# 2           0            1             2                     2
# 3           0            0             1                     2
# 4           0            0             1                     1
# ...       ...          ...           ...                   ...
# 17995       1            0             2                     1
# 17996       1            0             2                     1
# 17997       1            0             2                     1
# 17998       1            0             1                     1
# 17999       1            0             0                     2
#
#        Overdraft Protection  Credit Rating  # Credit Cards Held  \
# 0                         0              2                    2
# 1                         0              1                    2
# ...

# %%
Y = df2['Offer Accepted']
Y
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 17995    0
# 17996    0
# 17997    0
# 17998    0
# 17999    0
# Name: Offer Accepted, Length: 18000, dtype: int64

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=100)

model = GaussianNB()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
print('Accuracy: {:.2f}%'.format((y_pred == y_test).mean()*100))
# Out:
# Accuracy: 95.14%

# %%
print(classification_report(y_test, y_pred,zero_division=0))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.98      3425
#            1       0.00      0.00      0.00       175
#
#     accuracy                           0.95      3600
#    macro avg       0.48      0.50      0.49      3600
# weighted avg       0.91      0.95      0.93      3600

# %% [markdown]
# ## Deep Learning

# %%
X = df1.drop('Offer Accepted', axis='columns')
X
# Out:
#        Reward  Mailer Type  Income Level  # Bank Accounts Open  \
# 0           0            0             2                     1
# 1           0            0             1                     1
# 2           0            1             2                     2
# 3           0            0             1                     2
# 4           0            0             1                     1
# ...       ...          ...           ...                   ...
# 17995       1            0             2                     1
# 17996       1            0             2                     1
# 17997       1            0             2                     1
# 17998       1            0             1                     1
# 17999       1            0             0                     2
#
#        Overdraft Protection  Credit Rating  # Credit Cards Held  \
# 0                         0              2                    2
# 1                         0              1                    2
# ...

# %%
Y = df1['Offer Accepted']
Y
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 17995    0
# 17996    0
# 17997    0
# 17998    0
# 17999    0
# Name: Offer Accepted, Length: 18000, dtype: int64

# %% [markdown]
# ### MLP

# %%
from sklearn.neural_network import MLPClassifier

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=100)

# create an MLP classifier
mlp = MLPClassifier(hidden_layer_sizes=(100, 50), activation='relu', solver='adam', max_iter=200)

# fit the model to the training data
mlp.fit(X_train, y_train)

# predict the labels for the test data
y_pred = mlp.predict(X_test)
# Out:
# C:\Users\nisha\AppData\Roaming\Python\Python39\site-packages\sklearn\neural_network\_multilayer_perceptron.py:679: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %%
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy: {:.2f}%".format(accuracy * 100))
# Out:
# Accuracy: 94.72%

# %% [markdown]
# ### ANN

# %%
from sklearn.neural_network import MLPRegressor
from sklearn.metrics import r2_score

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=100)

# create an ANN regressor
ann = MLPRegressor(hidden_layer_sizes=(100, 50), activation='relu', solver='adam', max_iter=200)

# fit the model to the training data
ann.fit(X_train, y_train)

# predict the labels for the test data
y_pred = ann.predict(X_test)
# Out:
# C:\Users\nisha\AppData\Roaming\Python\Python39\site-packages\sklearn\neural_network\_multilayer_perceptron.py:686: UserWarning: Training interrupted by user.
#   warnings.warn("Training interrupted by user.")

# %%
accuracy = r2_score(y_test, y_pred)
print("Accuracy: {:.2f}%".format(accuracy * 100))
# Out:
# Accuracy: 2.11%

# %%
from sklearn.neural_network import MLPRegressor
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=100)
# create a DNN regressor
dnn = MLPRegressor(hidden_layer_sizes=(100, 50, 25), activation='relu', solver='adam', max_iter=200)

# fit the model to the training data
dnn.fit(X_train, y_train)

# predict the labels for the test data
y_pred = dnn.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 2
#       1 from sklearn.neural_network import MLPRegressor
# ----> 2 X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=100)
#       3 # create a DNN regressor
#       4 dnn = MLPRegressor(hidden_layer_sizes=(100, 50, 25), activation='relu', solver='adam', max_iter=200)
#
# NameError: name 'train_test_split' is not defined

# %%
from sklearn.metrics import r2_score

# predict the labels for the test data
y_pred = dnn.predict(X_test)

# calculate the R-squared score
accuracy = r2_score(y_test, y_pred)

print('Accuracy:', accuracy)

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense


X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2)

# Define the ANN model
model = Sequential()
model.add(Dense(64, input_dim=X_train.shape[1], activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# Compile the model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train the model
model.fit(X_train, y_train, epochs=10, batch_size=32, validation_data=(X_test, y_test))
